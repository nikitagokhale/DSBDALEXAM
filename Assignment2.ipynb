# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('melb_data.csv')
data['Method'].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
df = pd.DataFrame({'Method':['S', 'SP', 'PI', 'VB', 'SA']})
encoded_data = pd.get_dummies(df)
print(encoded_data)
# Out:
#    Method_PI  Method_S  Method_SA  Method_SP  Method_VB
# 0          0         1          0          0          0
# 1          0         0          0          1          0
# 2          1         0          0          0          0
# 3          0         0          0          0          1
# 4          0         0          1          0          0

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df2 = pd.concat([data, encoded_data], axis=1)

# %%
df2.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  CouncilArea  Lattitude  Longtitude  \
# 0  3/12/2016       2.5    3067.0  ...        Yarra   -37.7996    144.9984
# 1  4/02/2016       2.5    3067.0  ...        Yarra   -37.8079    144.9934
# 2  4/03/2017       2.5    3067.0  ...        Yarra   -37.8093    144.9944
# 3  4/03/2017       2.5    3067.0  ...        Yarra   -37.7969    144.9969
# 4  4/06/2016       2.5    3067.0  ...        Yarra   -37.8072    144.9941
#
#               Regionname  Propertycount  Method_PI Method_S  Method_SA  \
# ...
